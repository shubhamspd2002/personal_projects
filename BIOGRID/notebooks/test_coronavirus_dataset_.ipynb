# %%
from biogrid.db.models import Interaction, Protein, Organism
from biogrid.db.manager import Importer, Query
import pandas as pd
import sqlalchemy 
import os
from sqlalchemy import Engine, create_engine
connection_string ='sqlite:///biogrid_coronavirus.db'

# %%
# This is the original dataset file. If you wish to move the data in the /tests/data folder, use this:
# os.path.join('tests', 'data', 'BIOGRID-CORONAVIRUS-4.4.242.tab3.tsv')
from typing import LiteralString
from pandas import DataFrame


original_corona_dataset_file_path: LiteralString = os.path.join('../BIOGRID-CORONAVIRUS-4.4.242.tab3.tsv')

# This line shows the dataframe. nrows= n shows only the first n rows and also copies these many rows later to a
# separate .tsv file which contains this mini data. You can change the rows to be displayed as you like.
# This is done because the large tsv file crashes the VS code in weaker computers when converting to a .db file
original_dataframe: DataFrame = pd.read_csv(filepath_or_buffer=original_corona_dataset_file_path, sep='\t', nrows=5000)
original_dataframe
# Out:
#         #BioGRID Interaction ID  \
# 141211                   850980
# 141212                   852501
# 141213                   850980
# 141214                   856680
# 141215                   852501
# ...                         ...
# 2792037                43740578
# 2792038                43740578
# 2792039                43740578
# 2792040                43740578
# 2792041                43740578
#
#         Entrez Gene Interactor A    Entrez Gene Interactor B  \
# 141211                                              852501
# 141212                                              850980
# 141213                                              856680
# 141214                                              850980
# 141215                                              850793
# ...                                                    ...
# 2792037                                               4677
# 2792038                                                488
# 2792039                                               5501
# 2792040                                               5910
# 2792041                                               6130
#
#          BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 141211                     31542                    32899
# 141212                     32899                    31542
# 141213                     31542                    36697
# 141214                     36697                    31542
# 141215                     32899                    31376
# ...                          ...                      ...
# 2792037                  4383851                   110758
# 2792038                  4383851                   106978
# 2792039                  4383851                   111495
# 2792040                  4383851                   111845
# 2792041                  4383851                   112050
#
#         Systematic Name Interactor A Systematic Name Interactor B  \
# 141211                       YLR274W                      YBR202W
# 141212                       YBR202W                      YLR274W
# 141213                       YLR274W                      YEL032W
# 141214                       YEL032W                      YLR274W
# 141215                       YBR202W                      YLR103C
# ...                              ...                          ...
# 2792037              GU280_gp01_nsp2                            -
# 2792038              GU280_gp01_nsp2                            -
# 2792039              GU280_gp01_nsp2                            -
# 2792040              GU280_gp01_nsp2                            -
# 2792041              GU280_gp01_nsp2           RP11-244N20.10-004
#
#         Official Symbol Interactor A Official Symbol Interactor B  \
# 141211                          MCM5                         MCM7
# 141212                          MCM7                         MCM5
# 141213                          MCM5                         MCM3
# 141214                          MCM3                         MCM5
# 141215                          MCM7                        CDC45
# ...                              ...                          ...
# 2792037                         nsp2                         NARS
# 2792038                         nsp2                       ATP2A2
# 2792039                         nsp2                       PPP1CC
# 2792040                         nsp2                     RAP1GDS1
# 2792041                         nsp2                        RPL7A
#
#                                      Synonyms Interactor A  \
# 141211   BOB1|CDC46|MCM DNA helicase complex subunit MC...
# 141212   CDC47|MCM DNA helicase complex subunit MCM7|L0...
# 141213   BOB1|CDC46|MCM DNA helicase complex subunit MC...
# 141214    MCM DNA helicase complex subunit MCM3|L000001039
# 141215   CDC47|MCM DNA helicase complex subunit MCM7|L0...
# ...                                                    ...
# 2792037  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 2792038  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 2792039  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 2792040  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 2792041  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
#
#                                      Synonyms Interactor B  ...  \
# 141211   CDC47|MCM DNA helicase complex subunit MCM7|L0...  ...
# 141212   BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 141213    MCM DNA helicase complex subunit MCM3|L000001039  ...
# 141214   BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 141215                                     SLD4|L000003380  ...
# ...                                                    ...  ...
# 2792037                                        ASNRS|NARS1  ...
# 2792038                                ATP2B|DAR|DD|SERCA2  ...
# 2792039                                   PP-1G|PP1C|PPP1G  ...
# 2792040                                        GDS1|SmgGDS  ...
# 2792041                                     L7A|SURF3|TRUP  ...
#
#         TREMBL Accessions Interactor B  \
# 141211                               -
# 141212                               -
# 141213                               -
# 141214                               -
# 141215                               -
# ...                                ...
# 2792037                              -
# 2792038                              -
# 2792039                     A0A024RBP2
# 2792040           B7Z4M5|B3KNU0|Q6U7G8
# 2792041                              -
#
#                             REFSEQ Accessions Interactor B Ontology Term IDs  \
# 141211                                           NP_009761                 -
# 141212                                           NP_013376                 -
# 141213                                           NP_010882                 -
# 141214                                           NP_013376                 -
# 141215                                           NP_013204                 -
# ...                                                    ...               ...
# 2792037                                          NP_004530                 -
# 2792038                                NP_001672|NP_733765                 -
# 2792039                             NP_001231903|NP_002701                 -
# 2792040  NP_066982|NP_001093900|NP_001093899|NP_0010938...                 -
# 2792041                                          NP_000963                 -
#
#         Ontology Term Names  Ontology Term Categories  \
# 141211                    -                         -
# 141212                    -                         -
# 141213                    -                         -
# 141214                    -                         -
# 141215                    -                         -
# ...                     ...                       ...
# 2792037                   -                         -
# 2792038                   -                         -
# 2792039                   -                         -
# 2792040                   -                         -
# 2792041                   -                         -
#
#          Ontology Term Qualifier IDs Ontology Term Qualifier Names  \
# 141211                             -                             -
# 141212                             -                             -
# 141213                             -                             -
# 141214                             -                             -
# 141215                             -                             -
# ...                              ...                           ...
# 2792037                            -                             -
# 2792038                            -                             -
# 2792039                            -                             -
# 2792040                            -                             -
# 2792041                            -                             -
#
#         Ontology Term Types                       Organism Name Interactor A  \
# 141211                    -                 Saccharomyces cerevisiae (S288c)
# 141212                    -                 Saccharomyces cerevisiae (S288c)
# 141213                    -                 Saccharomyces cerevisiae (S288c)
# 141214                    -                 Saccharomyces cerevisiae (S288c)
# 141215                    -                 Saccharomyces cerevisiae (S288c)
# ...                     ...                                              ...
# 2792037                   -  Severe acute respiratory syndrome coronavirus 2
# 2792038                   -  Severe acute respiratory syndrome coronavirus 2
# 2792039                   -  Severe acute respiratory syndrome coronavirus 2
# 2792040                   -  Severe acute respiratory syndrome coronavirus 2
# 2792041                   -  Severe acute respiratory syndrome coronavirus 2
#
#                Organism Name Interactor B
# 141211   Saccharomyces cerevisiae (S288c)
# 141212   Saccharomyces cerevisiae (S288c)
# 141213   Saccharomyces cerevisiae (S288c)
# 141214   Saccharomyces cerevisiae (S288c)
# 141215   Saccharomyces cerevisiae (S288c)
# ...                                   ...
# 2792037                      Homo sapiens
# 2792038                      Homo sapiens
# 2792039                      Homo sapiens
# 2792040                      Homo sapiens
# 2792041                      Homo sapiens
#
# [5000 rows x 36 columns]

# %%
# Define the file path
from typing import LiteralString
import csv
corona_file_path: LiteralString = os.path.join('../tests', 'data', 'BIOGRID-CORONAVIRUS-test.tsv')

# %%
# Save the DataFrame to a TSV file, overwriting if it already exists
# Without the quoting argument, the function .to_csv() encloses all the words in quotes which creates problems
# # escapechar = '\\' needs to be added when quoting= is used 
original_dataframe.to_csv(path_or_buf=corona_file_path, sep='\t', index=False, quoting=csv.QUOTE_NONE, escapechar='\\')

# %%
from typing import LiteralString
df: pd.DataFrame = pd.read_csv(filepath_or_buffer=corona_file_path, sep='\t')
df
# Out:
#      #BioGRID Interaction ID  \
# 0                     850980
# 1                     852501
# 2                     850980
# 3                     856680
# 4                     852501
# ...                      ...
# 4995                43740578
# 4996                43740578
# 4997                43740578
# 4998                43740578
# 4999                43740578
#
#      Entrez Gene Interactor A    Entrez Gene Interactor B  \
# 0                                                852501
# 1                                                850980
# 2                                                856680
# 3                                                850980
# 4                                                850793
# ...                                                 ...
# 4995                                               4677
# 4996                                                488
# 4997                                               5501
# 4998                                               5910
# 4999                                               6130
#
#       BioGRID ID Interactor A  BioGRID ID Interactor B  \
# 0                       31542                    32899
# 1                       32899                    31542
# 2                       31542                    36697
# 3                       36697                    31542
# 4                       32899                    31376
# ...                       ...                      ...
# 4995                  4383851                   110758
# 4996                  4383851                   106978
# 4997                  4383851                   111495
# 4998                  4383851                   111845
# 4999                  4383851                   112050
#
#      Systematic Name Interactor A Systematic Name Interactor B  \
# 0                         YLR274W                      YBR202W
# 1                         YBR202W                      YLR274W
# 2                         YLR274W                      YEL032W
# 3                         YEL032W                      YLR274W
# 4                         YBR202W                      YLR103C
# ...                           ...                          ...
# 4995              GU280_gp01_nsp2                            -
# 4996              GU280_gp01_nsp2                            -
# 4997              GU280_gp01_nsp2                            -
# 4998              GU280_gp01_nsp2                            -
# 4999              GU280_gp01_nsp2           RP11-244N20.10-004
#
#      Official Symbol Interactor A Official Symbol Interactor B  \
# 0                            MCM5                         MCM7
# 1                            MCM7                         MCM5
# 2                            MCM5                         MCM3
# 3                            MCM3                         MCM5
# 4                            MCM7                        CDC45
# ...                           ...                          ...
# 4995                         nsp2                         NARS
# 4996                         nsp2                       ATP2A2
# 4997                         nsp2                       PPP1CC
# 4998                         nsp2                     RAP1GDS1
# 4999                         nsp2                        RPL7A
#
#                                   Synonyms Interactor A  \
# 0     BOB1|CDC46|MCM DNA helicase complex subunit MC...
# 1     CDC47|MCM DNA helicase complex subunit MCM7|L0...
# 2     BOB1|CDC46|MCM DNA helicase complex subunit MC...
# 3      MCM DNA helicase complex subunit MCM3|L000001039
# 4     CDC47|MCM DNA helicase complex subunit MCM7|L0...
# ...                                                 ...
# 4995  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 4996  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 4997  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 4998  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
# 4999  ORF1ab|ORF1ab-nsp2|SARS-CoV2 nsp2|SARS-CoV-2 n...
#
#                                   Synonyms Interactor B  ...  \
# 0     CDC47|MCM DNA helicase complex subunit MCM7|L0...  ...
# 1     BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 2      MCM DNA helicase complex subunit MCM3|L000001039  ...
# 3     BOB1|CDC46|MCM DNA helicase complex subunit MC...  ...
# 4                                       SLD4|L000003380  ...
# ...                                                 ...  ...
# 4995                                        ASNRS|NARS1  ...
# 4996                                ATP2B|DAR|DD|SERCA2  ...
# 4997                                   PP-1G|PP1C|PPP1G  ...
# 4998                                        GDS1|SmgGDS  ...
# 4999                                     L7A|SURF3|TRUP  ...
#
#      TREMBL Accessions Interactor B  \
# 0                                 -
# 1                                 -
# 2                                 -
# 3                                 -
# 4                                 -
# ...                             ...
# 4995                              -
# 4996                              -
# 4997                     A0A024RBP2
# 4998           B7Z4M5|B3KNU0|Q6U7G8
# 4999                              -
#
#                          REFSEQ Accessions Interactor B Ontology Term IDs  \
# 0                                             NP_009761                 -
# 1                                             NP_013376                 -
# 2                                             NP_010882                 -
# 3                                             NP_013376                 -
# 4                                             NP_013204                 -
# ...                                                 ...               ...
# 4995                                          NP_004530                 -
# 4996                                NP_001672|NP_733765                 -
# 4997                             NP_001231903|NP_002701                 -
# 4998  NP_066982|NP_001093900|NP_001093899|NP_0010938...                 -
# 4999                                          NP_000963                 -
#
#      Ontology Term Names  Ontology Term Categories  \
# 0                      -                         -
# 1                      -                         -
# 2                      -                         -
# 3                      -                         -
# 4                      -                         -
# ...                  ...                       ...
# 4995                   -                         -
# 4996                   -                         -
# 4997                   -                         -
# 4998                   -                         -
# 4999                   -                         -
#
#       Ontology Term Qualifier IDs Ontology Term Qualifier Names  \
# 0                               -                             -
# 1                               -                             -
# 2                               -                             -
# 3                               -                             -
# 4                               -                             -
# ...                           ...                           ...
# 4995                            -                             -
# 4996                            -                             -
# 4997                            -                             -
# 4998                            -                             -
# 4999                            -                             -
#
#      Ontology Term Types                       Organism Name Interactor A  \
# 0                      -                 Saccharomyces cerevisiae (S288c)
# 1                      -                 Saccharomyces cerevisiae (S288c)
# 2                      -                 Saccharomyces cerevisiae (S288c)
# 3                      -                 Saccharomyces cerevisiae (S288c)
# 4                      -                 Saccharomyces cerevisiae (S288c)
# ...                  ...                                              ...
# 4995                   -  Severe acute respiratory syndrome coronavirus 2
# 4996                   -  Severe acute respiratory syndrome coronavirus 2
# 4997                   -  Severe acute respiratory syndrome coronavirus 2
# 4998                   -  Severe acute respiratory syndrome coronavirus 2
# 4999                   -  Severe acute respiratory syndrome coronavirus 2
#
#             Organism Name Interactor B
# 0     Saccharomyces cerevisiae (S288c)
# 1     Saccharomyces cerevisiae (S288c)
# 2     Saccharomyces cerevisiae (S288c)
# 3     Saccharomyces cerevisiae (S288c)
# 4     Saccharomyces cerevisiae (S288c)
# ...                                ...
# 4995                      Homo sapiens
# 4996                      Homo sapiens
# 4997                      Homo sapiens
# 4998                      Homo sapiens
# 4999                      Homo sapiens
#
# [5000 rows x 36 columns]

# %%
engine: Engine = create_engine(connection_string)
# The path for the .tsv file containing the small dataset is used here
importer = Importer(engine=engine, file_path=corona_file_path) 
loaded_data = importer.load_data()
loaded_data
# Out:
#      biogrid_interaction_id official_symbol_interactor_a  \
# 0                    850980                         MCM5
# 1                    852501                         MCM7
# 2                    850980                         MCM5
# 3                    856680                         MCM3
# 4                    852501                         MCM7
# ...                     ...                          ...
# 4995               43740578                         nsp2
# 4996               43740578                         nsp2
# 4997               43740578                         nsp2
# 4998               43740578                         nsp2
# 4999               43740578                         nsp2
#
#      official_symbol_interactor_b experimental_system  \
# 0                            MCM7          Two-hybrid
# 1                            MCM5          Two-hybrid
# 2                            MCM3          Two-hybrid
# 3                            MCM5          Two-hybrid
# 4                           CDC45          Two-hybrid
# ...                           ...                 ...
# 4995                         NARS  Proximity Label-MS
# 4996                       ATP2A2  Proximity Label-MS
# 4997                       PPP1CC  Proximity Label-MS
# 4998                     RAP1GDS1  Proximity Label-MS
# 4999                        RPL7A  Proximity Label-MS
#
#      experimental_system_type  organism_id_interactor_a  \
# 0                    physical                    559292
# 1                    physical                    559292
# 2                    physical                    559292
# 3                    physical                    559292
# 4                    physical                    559292
# ...                       ...                       ...
# 4995                 physical                   2697049
# 4996                 physical                   2697049
# 4997                 physical                   2697049
# 4998                 physical                   2697049
# 4999                 physical                   2697049
#
#       organism_id_interactor_b  score swiss_prot_accessions_interactor_a  \
# 0                       559292      -                             P29496
# 1                       559292      -                             P38132
# 2                       559292      -                             P29496
# 3                       559292      -                             P24279
# 4                       559292      -                             P38132
# ...                        ...    ...                                ...
# 4995                      9606    2.5                             P0DTD1
# 4996                      9606   3.55                             P0DTD1
# 4997                      9606    6.1                             P0DTD1
# 4998                      9606   7.32                             P0DTD1
# 4999                      9606  18.03                             P0DTD1
#
#      swiss_prot_accessions_interactor_b  \
# 0                                P38132
# 1                                P29496
# 2                                P24279
# 3                                P29496
# 4                                Q08032
# ...                                 ...
# 4995                             O43776
# 4996                             P16615
# 4997                             P36873
# 4998                             P52306
# 4999                             P62424
#
#                            organism_name_interactor_a  \
# 0                    Saccharomyces cerevisiae (S288c)
# 1                    Saccharomyces cerevisiae (S288c)
# 2                    Saccharomyces cerevisiae (S288c)
# 3                    Saccharomyces cerevisiae (S288c)
# 4                    Saccharomyces cerevisiae (S288c)
# ...                                               ...
# 4995  Severe acute respiratory syndrome coronavirus 2
# 4996  Severe acute respiratory syndrome coronavirus 2
# 4997  Severe acute respiratory syndrome coronavirus 2
# 4998  Severe acute respiratory syndrome coronavirus 2
# 4999  Severe acute respiratory syndrome coronavirus 2
#
#             organism_name_interactor_b
# 0     Saccharomyces cerevisiae (S288c)
# 1     Saccharomyces cerevisiae (S288c)
# 2     Saccharomyces cerevisiae (S288c)
# 3     Saccharomyces cerevisiae (S288c)
# 4     Saccharomyces cerevisiae (S288c)
# ...                                ...
# 4995                      Homo sapiens
# 4996                      Homo sapiens
# 4997                      Homo sapiens
# 4998                      Homo sapiens
# 4999                      Homo sapiens
#
# [5000 rows x 12 columns]

# %%
# This is just for debugging purposes to find any primary keys which are repeated. If repeated then it gives an error when importing the data using .import_data():
# An error occurred: (sqlite3.IntegrityError) UNIQUE constraint failed: protein.uniprot_id

df_proteins = importer.get_proteins_df(df)
duplicates = df_proteins[df_proteins.duplicated(subset=['uniprot_id'], keep=False)]
print("Duplicate Proteins Found:\n", duplicates)
# Out:
# Duplicate Proteins Found:
#  Empty DataFrame
# Columns: [uniprot_id, symbol, tax_id]
# Index: []

# %%
# This is just for debugging purposes to find any primary keys which are repeated.
df_organisms = importer.get_organisms_df(df)
duplicates = df_organisms[df_organisms.duplicated(subset=['tax_id'], keep=False)]
print("Duplicate Organisms Found:\n", duplicates)
# Out:
# Duplicate Organisms Found:
#  Empty DataFrame
# Columns: [tax_id, name]
# Index: []

# %%
# This is just for debugging purposes to find any primary keys which are repeated.
df_organisms = importer.get_interaction_df(df)
duplicates = df_organisms[df_organisms.duplicated(subset=['id'], keep=False)]
print("Duplicate Interaction Found:\n", duplicates)
# Out:
# Duplicate Interaction Found:
#  Empty DataFrame
# Columns: [id, interactor_a_id, interactor_b_id, score, experimental_system, experimental_system_type]
# Index: []

# %%
importer.import_data()

# %%
importer.get_interaction_df(loaded_data)
# Out:
#          id interactor_a_id interactor_b_id score       experimental_system  \
# 0    850980          P29496          P38132  None                Two-hybrid
# 1    852501          P38132          P29496  None                Two-hybrid
# 2    856680          P24279          P29496  None                Two-hybrid
# 3    854391          Q12234          P40395  None       Synthetic Lethality
# 4       595          P24385          P03372  None  Affinity Capture-Western
# ..      ...             ...             ...   ...                       ...
# 99    79412          Q8NCW0          P0DTC2  None     Reconstituted Complex
# 100   10288            None          P0DTC2  None     Reconstituted Complex
# 101   10960          Q12907          P0DTC2  None     Reconstituted Complex
# 102    4247          Q10469          P0DTC2  None     Reconstituted Complex
# 103   27180          Q9Y336          P0DTC2  None     Reconstituted Complex
#
#     experimental_system_type
# 0                   physical
# 1                   physical
# 2                   physical
# 3                    genetic
# 4                   physical
# ..                       ...
# 99                  physical
# 100                 physical
# 101                 physical
# 102                 physical
# 103                 physical
#
# [104 rows x 6 columns]

# %%
importer.get_proteins_df(loaded_data)
# Out:
#      uniprot_id  symbol  tax_id
# 0        P29496    MCM5  559292
# 1        P38132    MCM7  559292
# 2        P24279    MCM3  559292
# 3        Q12234    RUD3  559292
# 4        P24385   CCND1    9606
# ...         ...     ...     ...
# 2446     Q13136  PPFIA1    9606
# 2447     O00170     AIP    9606
# 2448     P31749    AKT1    9606
# 2449     Q9UMY4   SNX12    9606
# 2450     P36873  PPP1CC    9606
#
# [2451 rows x 3 columns]

# %%
importer.get_organisms_df(loaded_data)
# Out:
#     tax_id                                               name
# 0   559292                   Saccharomyces cerevisiae (S288c)
# 1     9606                                       Homo sapiens
# 2  2697049    Severe acute respiratory syndrome coronavirus 2
# 3   694009  Severe acute respiratory syndrome-related coro...
# 4    10029                                 Cricetulus griseus
# 5  1335626  Middle-East Respiratory Syndrome-related Coron...
# 6     9986                              Oryctolagus cuniculus
# 7     9685                                        Felis Catus
# 8     9615                                   Canis familiaris
# 9     9544                                     Macaca mulatta

# %%
query = Query(engine=engine)
query.count_interactions()
# Out:
# Number of interactions:
# 102

# %%
query.count_proteins()
# Out:
# Number of proteins:
# 2450

# %%
query.count_proteins()
# Out:
# Number of proteins:
# 2450
